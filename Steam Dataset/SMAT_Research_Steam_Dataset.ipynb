# %% [markdown]
# # **Read Data**

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
steam = pd.read_csv('Data Steam.csv')
steam.head() #read top 5 data
# Out:
#    steam_appid                                         categories  genres  \
# 0          730  ['Multi-player', 'Steam Achievements', 'Full c...  Action
# 1          570  ['Multi-player', 'Co-op', 'Steam Trading Cards...  Action
# 2       578080  ['Multi-player', 'PvP', 'Online PvP', 'Stats',...  Action
# 3      1172470  ['Multi-player', 'PvP', 'Online PvP', 'Co-op',...  Action
# 4      1446780  ['Single-player', 'Multi-player', 'Co-op', 'On...  Action
#
#                                         header_image  \
# 0  https://cdn.akamai.steamstatic.com/steam/apps/...
# 1  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2  https://cdn.akamai.steamstatic.com/steam/apps/...
# 3  https://cdn.akamai.steamstatic.com/steam/apps/...
# 4  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                    short_description  \
# 0  Counter-Strike: Global Offensive (CS: GO) expa...
# 1  Every day, millions of players worldwide enter...
# 2  Play PUBG: BATTLEGROUNDS for free. Land on str...
# 3  Apex Legends is the award-winning, free-to-pla...
# 4  Rise to the challenge and join the hunt! In Mo...
#
#                                name                         developer  \
# 0  Counter-Strike: Global Offensive  Valve, Hidden Path Entertainment
# 1                            Dota 2                             Valve
# 2               PUBG: BATTLEGROUNDS                     KRAFTON, Inc.
# 3                      Apex Legends             Respawn Entertainment
# 4               MONSTER HUNTER RISE                  CAPCOM Co., Ltd.
#
#           publisher  price     ccu  score
# 0             Valve      0  746122     83
# 1             Valve      0  581058     90
# 2     KRAFTON, Inc.      0  313078     56
# 3   Electronic Arts      0  243474     88
# 4  CAPCOM Co., Ltd.   5999  123539     87

# %%
steam.to_excel('steam.xlsx')

# %% [markdown]
# # **Checking Data dan Data Cleaning Process**

# %%
steam.isnull()
# Out:
#       steam_appid  categories  genres  header_image  short_description   name  \
# 0           False       False   False         False              False  False
# 1           False       False   False         False              False  False
# 2           False       False   False         False              False  False
# 3           False       False   False         False              False  False
# 4           False       False   False         False              False  False
# ...           ...         ...     ...           ...                ...    ...
# 2914        False       False   False         False              False  False
# 2915        False       False   False         False              False  False
# 2916        False       False   False         False              False  False
# 2917        False       False   False         False              False  False
# 2918        False       False   False         False              False  False
#
#       developer  publisher  price    ccu  score
# 0         False      False  False  False  False
# 1         False      False  False  False  False
# 2         False      False  False  False  False
# 3         False      False  False  False  False
# 4         False      False  False  False  False
# ...         ...        ...    ...    ...    ...
# 2914      False      False  False  False  False
# 2915      False      False  False  False  False
# 2916      False      False  False  False  False
# 2917      False      False  False  False  False
# 2918      False      False  False  False  False
#
# [2919 rows x 11 columns]

# %%
steam.isnull().sum()
# Out:
# steam_appid          0
# categories           0
# genres               0
# header_image         0
# short_description    0
# name                 0
# developer            0
# publisher            0
# price                0
# ccu                  0
# score                0
# dtype: int64

# %% [markdown]
# # **Genre and Score Data Grouping**

# %%
group_gs = pd.DataFrame(steam, columns=["genres","score"])
grouped_gs = group_gs.groupby(["genres"])
sort_gs = grouped_gs.mean()
sort_gs.sort_values('score', ascending=False)
# Out:
#                            score
# genres
# Game Development       97.000000
# Web Publishing         93.000000
# Software Training      91.000000
# Early Access           90.000000
# Aventure               89.000000
# Violent                87.500000
# Design & Illustration  85.333333
# Indie                  83.806452
# Animation & Modeling   83.538462
# Adventure              83.456633
# Utilities              82.850000
# Casual                 82.668033
# Azione                 81.500000
# RPG                    81.400000
# Strategy               81.344828
# Rekreacyjne            81.000000
# Racing                 80.403509
# Action                 80.009036
# Massively Multiplayer  79.333333
# Niezależne             79.000000
# Sports                 78.000000
# Simulation             77.235669
# Free to Play           75.459770
# Audio Production       65.500000

# %%
group_gs = pd.DataFrame(steam, columns=["genres","score"])
grouped_gs = group_gs.groupby(["genres"])
sort_gs = grouped_gs.count()
sort_gs.sort_values('score', ascending=False)
# Out:
#                        score
# genres
# Action                  1328
# Adventure                392
# Indie                    279
# Casual                   244
# RPG                      160
# Simulation               157
# Strategy                 145
# Free to Play              87
# Racing                    57
# Utilities                 20
# Animation & Modeling      13
# Sports                    12
# Massively Multiplayer      6
# Design & Illustration      6
# Azione                     2
# Audio Production           2
# Violent                    2
# Niezależne                 1
# Game Development           1
# Early Access               1
# Rekreacyjne                1
# Software Training          1
# Aventure                   1
# Web Publishing             1

# %%
sort_gs = sort_gs.sort_values('score', ascending=False)
sort_gs.head(5)
# Out:
#            score
# genres
# Action      1328
# Adventure    392
# Indie        279
# Casual       244
# RPG          160

# %%
sort_gs.to_excel('gs.xlsx')

# %% [markdown]
# # **Publisher and Score Data Grouping**

# %%
group_ps = pd.DataFrame(steam, columns=["publisher","score"])
grouped_ps = group_ps.groupby(["publisher"])
sort_ps = grouped_ps.mean()
sort_ps.sort_values('score', ascending=False)
# Out:
#                     score
# publisher
# VisualArts           99.0
# Thermite Games       99.0
# Patrick Traynor      99.0
# poncle               99.0
# Studio Minus         99.0
# ...                   ...
# Amaterasu Software   40.0
# Ac Games             38.0
# Factus Games         38.0
# Picroma              37.0
# KISS ltd             31.0
#
# [1450 rows x 1 columns]

# %%
group_ps = pd.DataFrame(steam, columns=["publisher","score"])
grouped_ps = group_ps.groupby(["publisher"])
sort_ps = grouped_ps.count()
sort_ps.sort_values('score', ascending=False)
# Out:
#                             score
# publisher
# Electronic Arts                65
# SEGA                           62
# Square Enix                    55
# Ubisoft                        55
# Bethesda Softworks             38
# ...                           ...
# Heart Machine                   1
# Headup, Whisper Games           1
# Headup                          1
# HappyTall Game                  1
# （Hong Kong）GKD Game Studio      1
#
# [1450 rows x 1 columns]

# %%
sort_ps = sort_ps.sort_values('score', ascending=False)
sort_ps.head(5)
# Out:
#                     score
# publisher
# Electronic Arts        65
# SEGA                   62
# Square Enix            55
# Ubisoft                55
# Bethesda Softworks     38

# %%
sort_ps.to_excel('ps.xlsx')

# %% [markdown]
# # **Price and Score Data Grouping**

# %%
group_prs = pd.DataFrame(steam, columns=["price","score"])
bins = pd.IntervalIndex.from_tuples([(0,0.001), (0.001, np.max(group_prs["price"]) + 1)], closed='left')
key = list('AB')
group_prs['new'] = np.array(key)[pd.cut(group_prs["price"], bins = bins).cat.codes]
print (group_prs)
# Out:
#       price  score new
# 0         0     83   A
# 1         0     90   A
# 2         0     56   A
# 3         0     88   A
# 4      5999     87   B
# ...     ...    ...  ..
# 2914   1499     84   B
# 2915   1199     97   B
# 2916    849     82   B
# 2917   3499     80   B
# 2918   3999     82   B
#
# [2919 rows x 3 columns]

# %%
new_group_prs = pd.DataFrame(group_prs, columns=["new","score"])
new_group_prs["new"] = new_group_prs["new"].replace(['A'],'FREE')
new_group_prs["new"] = new_group_prs["new"].replace(['B'],'PAID')

# %%
new_group_prs = new_group_prs.groupby(["new"])
sort_prs = new_group_prs.mean()
sort_prs.sort_values('score', ascending=False)
# Out:
#           score
# new
# PAID  81.689769
# FREE  77.480808

# %%
sort_prs.to_excel('prs_score.xlsx')

# %%
sort_prs = new_group_prs.count()
sort_prs.sort_values('score', ascending=False)
# Out:
#       score
# new
# PAID   2424
# FREE    495

# %%
sort_prs.plot(kind="bar", fontsize=10, colormap='viridis', figsize=(10, 5))

# %%
sort_prs.plot.pie(y='score', autopct='%.1f%%', figsize=(5, 5))

# %%
sort_prs.to_excel('prs_count.xlsx')

# %% [markdown]
# # **Genre & CCU**

# %%
sort_gc = pd.DataFrame(steam, columns=["short_description","genres","ccu"])
sort_gc
# Out:
#                                       short_description      genres     ccu
# 0     Counter-Strike: Global Offensive (CS: GO) expa...      Action  746122
# 1     Every day, millions of players worldwide enter...      Action  581058
# 2     Play PUBG: BATTLEGROUNDS for free. Land on str...      Action  313078
# 3     Apex Legends is the award-winning, free-to-pla...      Action  243474
# 4     Rise to the challenge and join the hunt! In Mo...      Action  123539
# ...                                                 ...         ...     ...
# 2914  One of the most acclaimed adventure games of a...   Adventure      38
# 2915  It's the first ever chess variant with spatial...       Indie      38
# 2916  A Clothing collection ARPG. Create set propert...      Action      38
# 2917  Experience with TramSim the most modern tram s...      Casual      38
# 2918  The Operational Art of War IV is the new gener...  Simulation      38
#
# [2919 rows x 3 columns]

# %%
sort_gc = sort_gc.groupby(['genres']).sum()
sort_gc
# Out:
#                            ccu
# genres
# Action                 4592678
# Adventure               328306
# Animation & Modeling      5976
# Audio Production           178
# Aventure                   210
# Azione                     194
# Casual                  241114
# Design & Illustration     1847
# Early Access                95
# Free to Play             78636
# Game Development            91
# Indie                   302304
# Massively Multiplayer    40366
# Niezależne               33197
# RPG                     178731
# Racing                   57775
# Rekreacyjne               6015
# Simulation              418454
# Software Training           55
# Sports                    8244
# Strategy                210458
# Utilities                 9229
# Violent                    116
# Web Publishing             203

# %%
sort_gc = sort_gc.sort_values(by=['ccu'], ascending=False)
sort_gc = sort_gc.head(10)
sort_gc
# Out:
#                            ccu
# genres
# Action                 4592678
# Simulation              418454
# Adventure               328306
# Indie                   302304
# Casual                  241114
# Strategy                210458
# RPG                     178731
# Free to Play             78636
# Racing                   57775
# Massively Multiplayer    40366

# %%
sort_gc.plot(kind="barh", fontsize=10, colormap='viridis', figsize=(10, 5))
plt.xlim(30000, 5000000)
# Out:
# (30000.0, 5000000.0)

# %%
top10gen.to_excel('top10gen.xlsx')

# %% [markdown]
# # **Publisher & CCU**

# %%
data3 = pd.DataFrame(steam, columns=["short_description","publisher","ccu"])
data3
# Out:
#                                       short_description  \
# 0     Counter-Strike: Global Offensive (CS: GO) expa...
# 1     Every day, millions of players worldwide enter...
# 2     Play PUBG: BATTLEGROUNDS for free. Land on str...
# 3     Apex Legends is the award-winning, free-to-pla...
# 4     Rise to the challenge and join the hunt! In Mo...
# ...                                                 ...
# 2914  One of the most acclaimed adventure games of a...
# 2915  It's the first ever chess variant with spatial...
# 2916  A Clothing collection ARPG. Create set propert...
# 2917  Experience with TramSim the most modern tram s...
# 2918  The Operational Art of War IV is the new gener...
#
#                             publisher     ccu
# 0                               Valve  746122
# 1                               Valve  581058
# 2                       KRAFTON, Inc.  313078
# 3                     Electronic Arts  243474
# 4                    CAPCOM Co., Ltd.  123539
# ...                               ...     ...
# 2914          Double Fine Productions      38
# 2915  Conor Petersen, Thunkspace, LLC      38
# 2916                           XP Liu      38
# 2917                    Aerosoft GmbH      38
# 2918                  Slitherine Ltd.      38
#
# [2919 rows x 3 columns]

# %%
userpub = data3.groupby(['publisher']).sum()
userpub
# Out:
#                               ccu
# publisher
#  Cygames, Inc.                275
# (none)                        194
# 10 Chambers                  1666
# 101XP                          97
# 1047 Games                   1494
# ...                           ...
# 跪求愿望                         1237
# 香港商河洛互動娛樂股份有限公司               342
# 香港商河洛互動娛樂股份有限公司, 方块游戏         474
# 鬼谷工作室, Lightning Games      15001
# （Hong Kong）GKD Game Studio    197
#
# [1450 rows x 1 columns]

# %%
rankpub = userpub.sort_values(by=['ccu'], ascending=False)
top10pub = rankpub.head(10)
top10pub
# Out:
#                          ccu
# publisher
# Valve                1540209
# Electronic Arts       439208
# KRAFTON, Inc.         313078
# CAPCOM Co., Ltd.      158622
# Rockstar Games        153246
# Paradox Interactive   143236
# SEGA                  125107
# Bethesda Softworks    118234
# Studio Wildcard       111749
# Xbox Game Studios     107969

# %%
top10pub.plot(kind="barh", fontsize=10, colormap='viridis', figsize=(10, 5))
plt.xlim(30000, 5000000)
# Out:
# (30000.0, 5000000.0)

# %%
top10pub.to_excel('top10pub.xlsx')
